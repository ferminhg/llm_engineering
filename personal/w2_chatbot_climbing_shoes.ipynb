# %% [markdown]
# # Chatbot Climbing Shoes 🧗

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr

from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display

# %%
# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging

load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set")

# %%
# Initialize

openai = OpenAI()
MODEL = 'gpt-4o-mini'

# %%
system_message = "You are a helpful assistant. Expert in climbing shoes and climbing gear. You are given a description of a list of climbing shoes. Respond using markdown format"

# %%
# Simpler than in my video - we can easily create this function that calls OpenAI
# It's now just 1 line of code to prepare the input to OpenAI!

def chat(message, history):
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]

    print("History is:")
    print(history)
    print("And messages is:")
    print(messages)

    stream = openai.chat.completions.create(model=MODEL, messages=messages, stream=True)

    response = ""
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        yield response

# %%
# get climbing shoes details
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}


class ClimbingShoesLandingPage:
    shoes_links = []
    base_url = "https://www.climbingzone.es/"
    url = base_url + "pies-de-gato/"

    def __init__(self):
        response = requests.get(self.url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        products_div = soup.find('div', id='js-product-list')

    
        self.shoes_links = [link.get('href') for link in products_div.find_all('a')]


landing_page = ClimbingShoesLandingPage()
landing_page.shoes_links

# %%
class ClimbingShoesDetails:
    price = 'unknown'
    model = 'unknown'
    link = 'unknown'
    description = 'unknown'
    brand = 'unknown'

    def __init__(self, link):
        self.link = link
        self.response = requests.get(self.link, headers=headers)
        self.body = self.response.content
        self.soup = BeautifulSoup(self.body, 'html.parser')
        self.get_price()
        self.get_model()
        self.get_description()

    def get_price(self):
        price_div = self.soup.find('span', class_='price_with_tax price_pvp')
        if price_div:
            self.price = price_div.get_text(strip=True)

    def get_model(self):
        model_div = self.soup.find('h1', class_='product_name')
        if model_div:
            self.model = model_div.get_text(strip=True)

    def get_description(self):
        description_div = self.soup.find('div', id='description')
        if description_div:
            self.description = description_div.get_text(separator="\n", strip=True)

    def shoes_content(self):
        content = f"""
        Shoes content:\n
        Model: {self.model}\n
        Price: {self.price}\n
        Description: {self.description}\n
        Website: {self.link}\n\n
        """
        return content


example = ClimbingShoesDetails("https://www.climbingzone.es/pies-de-gato/1061-ondra-comp-la-sportiva.html")
example.shoes_content()
# Out:
# '\n        Shoes content:\n\n        Model: La Sportiva Ondra Comp\n\n        Price: 174,97\xa0€\n\n        Description: El\nOndra Comp es un pie de gato\npensado y desarrollado para ofrecer las mejores prestaciones en tus escaladas en rocódromo o sobre grandes desplomes en roca, ya que es un pie de gato muy blando que logra hacerte sentir hasta el más mínimo relieve en tus pies.\nCon el\nOndra Comp\ntendrás un pie de gato muy flexible para conseguir la mayor superfice de contacto y aumentar la fricción sobre volúmenes o presas grandes, sin olvidarnos que incorpora la palmilla patentada\nSenseGrip\nque le otorga una muy buena resistencia a la torsión justo bajo los dedos de los pies para las presas más pequeñas.\nAdemás de esto el\nOndra Comp\ncuenta con un engomado total en el upper para movimientos de empeine sobre volumenes, que incluso incluye una placa de protección para evitar los dolorosos dinámicos de empeine cuando no aciertas justo en el lugar donde debías. ¡Increible!\nEl Ondra Comp lleva el nombre del mejor escalador de la historia:\nAdam Ondra\n, quien ha diseñado este modelo para satisfacer las necesidades más exigentes en las competiciones de la Copa del Mundo o los Juegos Olímpicos\nCon el Ondra Comp tendrás un pie de gato con muchísimo ajuste, blando y muy sensible en la suela y un talón excepcional para resolver los movimientos más duros ya sea en resina o en tus escaladas en roca.\nCaracterísticas principales del Ondra Comp\n:\nPuntera\n: Perfil alto y más volumen, permite mayor movilidad y trabajo muscular del pie. Ideal para volúmenes planos y presas pequeñas en rocódromos, aunque pueda perder precisión en roca.\nSuela\n: Incluye la tecnología\nSenseGrip\n, con una zona central muy sensible y un arco exterior reforzado para un equilibrio entre soporte y sensibilidad.\nTalón\n: Más estrecho y blando que otros modelos de La Sportiva, mejora el ajuste y la forma en que el pie de gato trabaja como una sola pieza\nEmpeine\n: Engomado completo con zonas estriadas para una fricción superior y una pequeña almohadilla que protege en movimientos agresivos de empeine\nAjuste\n: Horma intermedia y velcro que aseguran un ajuste cómodo y eficiente, adaptable a diferentes anchuras de pie.\nCierre: \xa0\xa0 Velcro\nTipo de suela de pies de gato\xa0\xa0\xa0 Suela curva\nTecnología: \xa0\xa0 P3 - SenseGrip\nAsimetría: \xa0\xa0 Agresivo\nUpper: \xa0\xa0 Piel ante\nGoma de la suela\xa0\xa0\xa0 Vibram XS Grip²\nDureza: Muy blando\nGénero\xa0\xa0\xa0 Unisex\nHorma \xa0\xa0 Estrecha\nTalla recomendada - Principiante: \xa0\xa0 Media talla menos del calzado de calle\nTalla recomendada - Intermedio\xa0\xa0\xa0 1 talla menos del calzado de calle\nTalla recomendada - Experto\xa0\xa0\xa0 2 tallas menos del calzado de calle\n\n        Website: https://www.climbingzone.es/pies-de-gato/1061-ondra-comp-la-sportiva.html\n\n\n        '

# %%
climbing_shoes_details = []
for link in landing_page.shoes_links:
    climbing_shoes_details.append(ClimbingShoesDetails(link))

print(climbing_shoes_details)
# Out:
# [<__main__.ClimbingShoesDetails object at 0x169b02090>, <__main__.ClimbingShoesDetails object at 0x169b01f50>, <__main__.ClimbingShoesDetails object at 0x175eeca90>, <__main__.ClimbingShoesDetails object at 0x168fb1ed0>, <__main__.ClimbingShoesDetails object at 0x14fb95010>, <__main__.ClimbingShoesDetails object at 0x16906b590>, <__main__.ClimbingShoesDetails object at 0x175fd23d0>, <__main__.ClimbingShoesDetails object at 0x175eab650>, <__main__.ClimbingShoesDetails object at 0x175e72210>, <__main__.ClimbingShoesDetails object at 0x175fa5ad0>, <__main__.ClimbingShoesDetails object at 0x175d6f190>, <__main__.ClimbingShoesDetails object at 0x177ce4cd0>, <__main__.ClimbingShoesDetails object at 0x30b8122d0>, <__main__.ClimbingShoesDetails object at 0x30ccea510>, <__main__.ClimbingShoesDetails object at 0x30cedf890>, <__main__.ClimbingShoesDetails object at 0x30d1662d0>, <__main__.ClimbingShoesDetails object at 0x30d3c7e10>, <__main__.ClimbingShoesDetails object at 0x30d845710>, <__main__.ClimbingShoesDetails object at 0x1697ff850>, <__main__.ClimbingShoesDetails object at 0x30dcf9690>, <__main__.ClimbingShoesDetails object at 0x30dd03e10>, <__main__.ClimbingShoesDetails object at 0x30df15250>, <__main__.ClimbingShoesDetails object at 0x30e2d5ed0>, <__main__.ClimbingShoesDetails object at 0x30e2ebbd0>, <__main__.ClimbingShoesDetails object at 0x30e529ed0>, <__main__.ClimbingShoesDetails object at 0x30e71b550>, <__main__.ClimbingShoesDetails object at 0x30e9434d0>, <__main__.ClimbingShoesDetails object at 0x30eba4d10>, <__main__.ClimbingShoesDetails object at 0x30ed77f50>, <__main__.ClimbingShoesDetails object at 0x30ef9ec10>]

# %%
system_message = "You are a helpful assistant. Expert in climbing shoes and climbing gear.  Respond using markdown format. You are given a description of a list of climbing shoes with the following format: \n\n Shoes content:\n Model: {self.model}\n Price: {self.price}\n Description: {self.description}\n Website: {self.link}\n\n"

for detail in climbing_shoes_details:
    system_message += f"\n\n{detail.shoes_content()}"

print(system_message)
# Out:
# You are a helpful assistant. Expert in climbing shoes and climbing gear.  Respond using markdown format. You are given a description of a list of climbing shoes with the following format:
#
#  Shoes content:
#  Model: {self.model}
#  Price: {self.price}
#  Description: {self.description}
#  Website: {self.link}
#
#
#
#
#         Shoes content:
#
#         Model: Garra Kamae
#
#         Price: 61,50 €
#
#         Description: Modelo fabricado en piel natural, con suela de goma cocida de 4,5mm y 2 cierres de velcro que ofrece una comodidad excepcional.
# El Kamae permite introducirse en la escalada con muy buenas prestaciones y acabados. Es un pie de gato que te durará mucho tiempo
#
#         Website: https://www.climbingzone.es/pies-de-gato/558-kamae-garra.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Ondra Comp
#
#         Price: 174,97 €
#
#         Description: El
# Ondra Comp es un pie de gato
# pensado y desarrollado para ofrecer las mejores prestaciones en tus escaladas en rocódromo o sobre grandes desplomes en roca, ya que es un pie de gato muy blando que logra hacerte sentir hasta el más mínimo relieve en tus pies.
# Con el
# Ondra Comp
# tendrás un pie de gato muy flexible para conseguir la mayor superfice de contacto y aumentar la fricción sobre volúmenes o presas grandes, sin olvidarnos que incorpora la palmilla patentada
# SenseGrip
# que le otorga una muy buena resistencia a la torsión justo bajo los dedos de los pies para las presas más pequeñas.
# Además de esto el
# Ondra Comp
# cuenta con un engomado total en el upper para movimientos de empeine sobre volumenes, que incluso incluye una placa de protección para evitar los dolorosos dinámicos de empeine cuando no aciertas justo en el lugar donde debías. ¡Increible!
# El Ondra Comp lleva el nombre del mejor escalador de la historia:
# Adam Ondra
# , quien ha diseñado este modelo para satisfacer las necesidades más exigentes en las competiciones de la Copa del Mundo o los Juegos Olímpicos
# Con el Ondra Comp tendrás un pie de gato con muchísimo ajuste, blando y muy sensible en la suela y un talón excepcional para resolver los movimientos más duros ya sea en resina o en tus escaladas en roca.
# Características principales del Ondra Comp
# :
# Puntera
# : Perfil alto y más volumen, permite mayor movilidad y trabajo muscular del pie. Ideal para volúmenes planos y presas pequeñas en rocódromos, aunque pueda perder precisión en roca.
# Suela
# : Incluye la tecnología
# SenseGrip
# , con una zona central muy sensible y un arco exterior reforzado para un equilibrio entre soporte y sensibilidad.
# Talón
# : Más estrecho y blando que otros modelos de La Sportiva, mejora el ajuste y la forma en que el pie de gato trabaja como una sola pieza
# Empeine
# : Engomado completo con zonas estriadas para una fricción superior y una pequeña almohadilla que protege en movimientos agresivos de empeine
# Ajuste
# : Horma intermedia y velcro que aseguran un ajuste cómodo y eficiente, adaptable a diferentes anchuras de pie.
# Cierre:    Velcro
# Tipo de suela de pies de gato    Suela curva
# Tecnología:    P3 - SenseGrip
# Asimetría:    Agresivo
# Upper:    Piel ante
# Goma de la suela    Vibram XS Grip²
# Dureza: Muy blando
# Género    Unisex
# Horma    Estrecha
# Talla recomendada - Principiante:    Media talla menos del calzado de calle
# Talla recomendada - Intermedio    1 talla menos del calzado de calle
# Talla recomendada - Experto    2 tallas menos del calzado de calle
#
#         Website: https://www.climbingzone.es/pies-de-gato/1061-ondra-comp-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Solution Comp
#
#         Price: 139,97 €
#
#         Description: El modelo Solution de la Sportiva es considerado uno de los mejores pies de gato del mundo. Para algunos escaladores, sobre todo en competición, su característico talón redondeado y rígido no ofrece las mejores prestaciones, por eso La Sportiva, en colaboración de escaladores como Adam Ondra, ha rediseñado su talón para convertirlo en un modelo ideal para competición o roca donde necesitamos un talón que se adapte a presas más pequeñas o que ofrezca más fricción sobre la superficies de los volúmenes que tan de moda están en las competiciones.
# La puntera del Solution Comp
# La puntera de este pie de gato mantiene el mismo diseño y rendimiento que Solution clásico. Muy asimétrica y afilada para el mejor rendimiento cuando tenemos que pisar presas muy muy pequeñas.
# Mantiene la característica "bola" cóncava bajo los dedos que tan buen resultado ha dado y que ha conseguido que muchos escaladores sean verdaderos fanáticos de este pie de gato.
# La horma del Solution Comp
# La horma del Solution Comp es también exactamente igual al Solution, manteniendo forma, volumen y tallaje, por lo que será más fácil elegir talla si ya conocías el modelo anterior.
# Presenta una particularidad que no se puede pasar por alto, y es que es una horma más blanda que la que conocíamos hasta ahora, pensada precisamente para escalada indoor y competición donde no necesitaremos un pie de gato tan duro y donde necesitaba aumentar la sensibilidad.
# El talón del Solution Comp
# Esta es la gran novedad en este modelo. El talón del Solution es hiperconocido ya que supuso un cambio radical en el concepto de los talones de los pies de gato que se conocían cuando salió al mercando en 2007.
# Este concepto tiene muchos defensores pero también muchos detractores que lo consideran demasiado rígido y voluminoso para determinadas escaladas.
# Teniendo en cuenta esta característica y tratando de dar solución a las necesidades de la escalada de competición de hoy en día La Sportiva ha rediseñado el talón para darle menos volumen, más flexibilidad y sensibilidad y mayor rendimiento sobre superficies planas como son los volúmenes o presas gigantes  que puede encontrarte hoy en día en cualquier problema de escalada indoor.
# La reducción del talón hace también que el pie de gato sea menos rígido y logre mayor elasticidad consiguiendo que todo el pie de gato trabaje en conjunto dejando atrás el rendimiento aislado de talón y puntera.
# El
# pie de gato Solution Comp
# ofrece el mismo ajuste que el modelo Solution, con la misma precisión en la puntera y el mismo sistema de cierre Fast Lacing sobre el empeine, pero con un talón diferente. Ahora eres tu quién decido que versión es mejor
# Pie de gato evolucionado para mejorar las prestaciones en competición
# Fabricado en ante natural combinado con materiales sintéticos
# Sistema de Cierre Fast Lacing
# Lengueta de Licra tipo neopreno
# Sistema de ajuste y flexión P3
# Suela Vibram XSGrip2 de 3.5mm
#
#         Website: https://www.climbingzone.es/pies-de-gato/405-solution-comp-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Tenaya Tanta
#
#         Price: 76,37 €
#
#         Description: El Tanta es un pie de gato dirigido a quien busca un modelo de buenas prestaciones sin tener que gastarse mucho dinero. Un compañero ideal para todos los que están progresando o iniciándose en la escalada, que les permitirá llevarlo durante mucho tiempo, incluso horas, gracias a su diseño y confort.
# Cuenta con suela de goma cocida y está fabricado bajo la tecnología M4 de Tenaya.
# Dispone de una ligera curvatura en la puntera para mejorar la precisión y la comodidad.
# Características:
# Fabricado en microfibra, por lo que no cede demasiado con el uso.
# Cierre y ajuste con 2 veleros
# Forro de algodón con tratamiento TXT.
# Lengüeta de fuelle acorchado.
# Plantilla 2D multicapa estrechtex.
# Palmilla 2D PLT 10.
# Suela Goma cocida 4mm.
# Peso aproximado de 340 g.
#
#         Website: https://www.climbingzone.es/pies-de-gato/287-tanta-tenaya.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Tenaya Tarifa
#
#         Price: 132,75 €
#
#         Description: El modelo Tarifa es un pie de gato con una dureza justa, ofreciendo una resistencia a la torsión justa para pasos verticales sobre microcantos sin perder un ápice de sensibilidad en techos y desplomes.
# Ofrece una horma muy cómoda a pesar de su diseño curvado y agresivo, algo que se deja notar y se agradece cuando llevas un rato con los pies de gato puestos.
# Está fabricado en microfibra y cuenta con una suela XS Grip de Vibram
# Otras características:
# Lengüeta:
# Lycra bidireccional de dos capas
# Forro:
# Algodón tratamiento TXT
# Plantilla:
# 2D multicapa estrechtex
# Palmilla:
# Doble Palmilla GI 1.8 y TST 150
# Suela:
# Vibram XS Grip 3,5 mm.
# Peso:
# 340 grs.
#
#         Website: https://www.climbingzone.es/pies-de-gato/150-tarifa-tenaya.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Otaki
#
#         Price: 146,96 €
#
#         Description: El modelo
# Otaki
# de la marca italiana
# La Sportiva
# es una evolución del Miura VS, mejorando el talón de este clasico pie de gato y rediseñando la puntera y el ajuste para que se adapte a la perfección al pie de cada escalador. Lo sentiras como un auténtico guante, y verás como con el
# Otaki
# esto no es una frase hecha.
# Pie de gato para los más exigentes
# Si necesitas un pie de gato con el mejor rendimiento en micro cantos, regletas, agujeros, tacos... Este es el mejor pie de gato podrás encontrar, ya sea para escaladas verticales o tumbadas. Si los pies de tu vía o bulder son pequeños, el Otaki será tu mejor compañero.
# El nombre de Otaki viene del japonés y significa sable extremadamente afilado. No creas que el nombre está puesto al azar, esta zapatilla para escalada es capar de mantener tu pie clavado un regletas de 1mm o en micro agujeros donde otros pies de gato no ofrecen la superficie de apoyo necesario, o con la resistencia a la torsión que te permita progresar.
# La Sportiva cuenta con unos de los mejores equipos de diseño y desarrollo, lo que se nota a la hora de calzarse este pie de gato. El cierre de velcro lo hace comodísimo de calzar y la suela Vibram XS Edge son la mayor garantia de exito.
# Incorpora el nuevos sistema S-Heel que hace que los apoyos laterales o con el talón ofrezcan la restencia exacta sin perder un ápice de sensibildiad.
# El nuevo Otaki es una joya para los escaladores más exigentes.
# Tejido:
# Microfibra y piel ante
# Forro:
# Pacific Front
# Media suela:
# LaSpoFlex 1,1 mm + P3 System
# Suela:
# 4mm Vibram XS-Edge
# Peso:
# 470 g numero 39
#
#         Website: https://www.climbingzone.es/pies-de-gato/170-otaki-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Scarpa Instinct VSR
#
#         Price: 159,97 €
#
#         Description: Un pie de gato elaborado en base a las sugerencias de todos los escaladores patrocinados por la marca Scarpa, y que supone un equilibro excelente entre un pie de gato sensible y a la vez con una gran respuesta en apoyos mínimos tanto en canteos laterales como frontales.
# Su cierre de velcro y el diseño y construcción del propio pie de gato hacen que ciña al pie de forma excelente dando muy buena sensación en los apoyos por pequeños que sean.
# El talón también ofrece un rendimiento excelente. De volumen medio, tiene la virtud de ajustar perfecto prácticamente a todos los escaladores.
# Presenta un sistema de ajuste denominado por Scarpa como Bi-Tension Rand, que consigue mantener la tensión realizada sobre la puntera hasta el talón logrando que todo el pie de gato enfoque la tensión justo donde se necesita.
# Cuenta con una suela XGrip S2 de Vibram, con unas prestaciones de adherencia excelentes, que son una referencia en el mercado, con un espesor de 3,5 mm. El tamaño perfecto para quienes buscan durabilidad y sensibilidad.
# Peso:
# 430 gr (talla 40)
# Materiales:
# Microfibra
# Suela:
# XGrip S2 de Vibram
# Construcción:
# Bi-Tension Rand
#
#         Website: https://www.climbingzone.es/pies-de-gato/319-instinct-vsr-scarpa.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Scarpa Instinct VS
#
#         Price: 156,97 €
#
#         Description: El
# pie de gato Instinct VS
# está pensado para ser la solución perfecta cuando las pesas de pies son realmente pequeñas gracias a su suela XS Edge de 3mm que resiste la torsión como ninguna.
# Fabricado con la tecnologia Bi-Tension, hace que tanto el talón como el arco del pie transmitan toda la fuerza a los dedos cuando se pisan cantos pequeños, algo que sorprende cuanto más exigente sea el movimiento.
# Homa: Agresiva - curvada
# Empeine:Microsuede
# Media suela: Flexan
# Goma: Vibram® XS Edge; 3mm
# Peso: 215g; (Talla 40)
#
#         Website: https://www.climbingzone.es/pies-de-gato/247-instinct-vs-scarpa.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Tarántula Blue
#
#         Price: 78,97 €
#
#         Description: Si estás empezando a escalar y estás buscando un pie de gato cómodo y que te permita progresar sin tener un dolor insoportable, o ya llevas tiempo escalando pero quieras un buen pie de gato sin dejarte un ojo de la cara, el
# Tarántula de La Sportiva
# es el modelo ideal
# Cuenta con una puntera ligeramente asimétrica que permite escalar de forma eficaz tanto a escaladores principiantes como a aquellos que no necesitan pies de gato demasiado técnicos, y un ajuste cómodo que te permitirá utilizarlo prácticamente en cualquier modalidad de escalada, ya te guste escalar vías, bulder o prefieras la resina de tu rocódromo
# Monta una goma FriXion RS que consigue buenos resultados en adherencia logrando una mayor durabilidad para que tengas pies de gato para mucho tiempo.
# Cuenta con una parte superior sin forro para mejorar la transpiración del pie cuando hace más calor, y una lengüeta acolchada que facilitar el calzado y lo hace más cómodo durante todo el tiempo que lo llevas puesto.
# El Tarántula es un pie de gato para los que les gusta escalar y disfrutar de la escalada
# Exterior de piel ante
# Media suela  1.8mm Laspoflex que le da la dureza justa
# Suela FriXion RS de 4mm
# Peso 480 gr
#
#         Website: https://www.climbingzone.es/pies-de-gato/406-tarantula-azul-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Boreal Ninja
#
#         Price: 94,95 €
#
#         Description: Este modelo de pie de gato es ideal para los escaladores de resina o roca, de bloque o vías. Muy polivalente y cómodo.
# Con uno de los mejores ajustes del mercado el
# nuevo Ninja de Boreal
# es un pie de gato blando que sin embargo ofrece unas increíbles prestaciones en canteo sobre presa pequeña
# Fabricado en material sintético para evitar una deformación excesiva con el uso, monta una suela Zenith Ultra de 4/4,5mm según la talla. Además incorpora una media palmilla en la puntera que consigue que este pie de gato pueda rendir de forma increíble en pesas muy pequeñas para pies.
# Sin forro para una mayor sensibilidad y ajuste
#
#         Website: https://www.climbingzone.es/pies-de-gato/65-ninja-boreal.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Tenaya Iati
#
#         Price: 132,25 €
#
#         Description: El modelo
# IATI
# está pensado para escaladores exigentes y que necesitan un pie de gato de altas prestaciones, que sea capaz de aportar soluciones independientemente del tipo presa que pise.
# Es un pie de gato cómodo y algo más ancho en la horma que otros modelos de la marca española, pero que ajusta muy bien al pie y se adapta de forma excelente gracias al cierre de veclro que no deja ni un hueco de aire una vez puesto.
# Los materiales con los que esta fabricado este pie de gato mejoran sus prestaciones evitando grandes deformidades en cantos muy pequeños, facilitando así la sensibilidad y mejorando las sensaciones durante la escalada.
# Cuenta con el sistema SXR Dynamics que proporciona una movilidad extra a los dedos del pie ajustando perfectamente talón y puente.
# La puntera afilada y la asimetría de la horma hacen que sea un pie de gato muy preciso sobre cantos pequeños, algo que hay que tener muy en cuenta cuando los movimientos se vueleven más extremos.
# Material:
# Microfibra y Piel
# Cierre:
# Velcro, Sistema Draxtor® PATENTADO
# Lengüeta:
# Lycra bidireccional de dos capas
# Forro:
# Algodón tratamiento TXT
# Plantilla:
# 2D multicapa estrechtex
# Palmilla:
# Doble Palmilla GI 1.8 y TST 150
# Suela:
# Vibram XS Grip 3,5 mm.
# Peso:
# 340 hrs
#
#         Website: https://www.climbingzone.es/pies-de-gato/173-iati-tenaya.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Solution
#
#         Price: 139,97 €
#
#         Description: Los
# pies de gato Solution de La Sportiva
# son los pies de gato perfectos tanto para bulder como para las vías más duras.
# El Solution es un pie de gato de dureza media, que te ofrecerá el soporte necesario en la más pequeña regleta y toda la sensibilidad que necesites en el techo más duro al puedas enfrentarte.
# Si nos pides consejo, este es el mejor pie de gato, el que todo escalador quiere aunque no lo reconozca...
# Sistema de ajuste de velcro Lock Harness system®, y fabricado en Lorica®
# Suela Vibram® XSGrip2 3,5 mm
#
#         Website: https://www.climbingzone.es/pies-de-gato/43-solution-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Tenaya Ra hombre
#
#         Price: 118,35 €
#
#         Description: Construido sobre una horma con el mismo grado de asimetría que su predecesor el modelo Aqua , esta pensado para adaptarse a los requerimientos del pie en la escalada de máxima dificultad.
# Su combinación de materiales y el perfecto equilibrio entre todas sus prestaciones hace que sus resultados sean sorprendentes tanto sobre cantos difíciles y presas microscópicas como en los más duros trabajos de fricción y adherencia.
# SuelaVibram XS Grip 4mm
#
#         Website: https://www.climbingzone.es/pies-de-gato/70-ra-tenaya.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Testarossa
#
#         Price: 134,97 €
#
#         Description: El nuevo modelo Testarossa de La Sportiva cuanta con algunas mejoras muy notables, que hacen que un pie de gato ya era excepcional suba el nivel hasta convertirse en un imprescindible.
# Talón mejorado y un sistema de canteo especial, hacen que se distribuya la tensión de los apoyos por toda la planta, algo que se nota y mucho cuando de verdad hace falta
# Suela Vibram XSGrip2 3.5 mm
#
#         Website: https://www.climbingzone.es/pies-de-gato/46-testarossa-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Miura Woman
#
#         Price: 132,99 €
#
#         Description: Este pie de gato está especialmente diseñados para la escalada de alta dificultad adaptado a la morfología de pie de las chicas.
# Su forma asimétrica permite un canteo impresionante en minúsculas presas y agujeros sin perder sensibilidad y sin sentir la zapatilla como una tabla.
# El Miura Woman es un todoterreno que dará un rendimiento excelente tanto en resina como el vías de pared o en los bloques más exigentes.
# Excelente sujección, se siente como un guante
# Suela Vibram XS EDGE 4mms
#
#         Website: https://www.climbingzone.es/pies-de-gato/48-miura-woman-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Katana
#
#         Price: 125,90 €
#
#         Description: El
# pie de gato Katana de La Sportiva
# es un modelo polivalente que calzan muchos de los mejores escaladores del mundo en competiciones o en las vías más duras del mundo y hasta en las paredes más salvajes.
# Cuenta con una puntera asimétrica muy precisa, seguramente de las mejores de La Sportiva y una horma muy cómoda, lo que le ha supuesto que sea uno de los pies de gato más vendidos de la marca italiana.
# Es perfecto para utilizar sobre cantos extremadamente pequeños, donde podrás aprovechar todo su potencial
# Está fabricado en ante y microfibra y tiene un peso de 470 gramos el par (talla 39)
# Cuenta con una suela Vibram XS Edge de 4mm y un cierre de velcro excelente.
#
#         Website: https://www.climbingzone.es/pies-de-gato/158-katana-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Miura Lime
#
#         Price: 132,99 €
#
#         Description: El pie de gato
# Miura de La Sportiva
# revolucionó el concepto de pie de gato y es uno de los modelos más vendidos en el mundo usado para las vías y bloques más duros, y para las vías de pared dada su polivalencia y gran rendimiento.
# La puntera de este pie de gato ofrece una precisión quirúrjica, perfecta para minúsculas regleras o agujeros mínimos, donde este modelo demuestra de lo que es capaz.
# La adherencia es tambien uno de los fuertes de este pie de gato, que seguramente sea uno de los mejores pies de gato del mundo.
# Exterior:
# Ante, construcción tubular.
# Forro:
# Dentex.
# Suela Interior:
# LaSpoFlex 1,1 mm solo en la parte anterior.
# Suela:
# Vibram® XS Edge 4 mm
# Peso:
# 490 g (el par en media 39)
#
#         Website: https://www.climbingzone.es/pies-de-gato/160-miura-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Solution Woman
#
#         Price: 142,97 €
#
#         Description: El Solution Woman es un pie de gato de dureza media que aporta gran sensibilidad y un talón revolucionario que marca tendencia en otras marcas. Seguramente sea el pie de gato más completo del mercado en cualquier tipo de situación: Bulder, vías o competición.
# Si nos pides consejo, este es el mejor pie de gato, el que todo escalador quiere aunque no lo reconozca...
#
#         Website: https://www.climbingzone.es/pies-de-gato/171-solution-woman-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Skwama
#
#         Price: 140,97 €
#
#         Description: El modelo
# Skawama de La Sportiva
# es uno de los pies de gato en el concepto de bailaria más completos del mercado, en el que se nota que la marca italiana ha puesto toda su experiencia al servicio del diseño, logrando un pie de gato con unas prestaciones excepcionales.
# El Skwama podría verse como una evolución del modelo Python pero es mucho más que eso, de hecho, prácticamente no tiene nada que ver.
# Una horma algo más ancha de lo que La Sportiva nos tenía acostumbrados y una construcción tubular hacen que los dedos no se sientan tan aprisionados y se pueda sentir hasta el más minimo relieve de la roca.
# La nueva horma performada presenta una solided muy buena lo que aporta al pie de gato una sensación de estabilidad y control muy altas.
# El talón es la nueva propuesta de La Sportiva, que también lo incorpora el modelo
# Otaki
# , y que sin resultar tan duro como el del modelo Solution, presenta una rigidez más que adecuada para la mayoría de problemas tanto en vía como en bulder.
# Exterior: Microfibra en combinaciòn con piel de ante, construcciòn tubular
# Forro: No
# Ajuste: Medio
# Media Suela: LaSpoFlex 0,8 mm + P3 System
# Suela: Vibram® XS Grip2 4 mm
# Peso: 420 g (el par en media 39)
# Decir que el ajuste de este pie de gato es excelente, y las sensaciones nada mas calzarnosle excepcionales
#
#         Website: https://www.climbingzone.es/pies-de-gato/174-skwama.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Scarpa Drago
#
#         Price: 152,97 €
#
#         Description: Este pie de gato es un de los modelos más demandados gracias a sus prestaciones y comodidad.
# La forma de fabricación hace que el ajuste al pie sea perfecto, con la tensión perfecta sobre el arco del pie, lo que hace que los dedos estén más cómodos y permitan hacer más fuerza cuando se pisa microregletas
# Cuenta con cierre de un sólo velcro, que junto con el elástico del empeine convierten la tarea de calzarse en una competición de ver quien tarda menos.
# Horma:
# Agresiva-curvada
# Material:
# Microfibra sintética
# Construcción:
# Tecnología PCB
# Suela:
# Vibram XGrip 2 3.5 mm
# Peso:
# 200g (talla 40)
#
#         Website: https://www.climbingzone.es/pies-de-gato/246-drago-scarpa.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Tenaya Indalo
#
#         Price: 148,97 €
#
#         Description: El Indalo es un pie de gato de alto rendimiento pensado para las vías y bloques más exigentes, ya sea en roca o sobre resina.
# Este modelo ofrece una asimetría maestra para alcanzar niveles de precisión máxima cuando necesitamos pisar con la puntera en presas mínimas. Cuenta con una horma muy equilibrada para un ajuste óptimo, y un sistema de construcción de media suela que logra que tanto la suela, el arco y el talón trabajen para juntos para una sensación de control total sobre los pies
#
#         Website: https://www.climbingzone.es/pies-de-gato/689-indalo-tenaya.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Tenaya Ra Woman
#
#         Price: 118,35 €
#
#         Description: El modelo Ra Woman de la marca española Tenaya es ideal para quienes tiene pies con poco volumen y buscan un pie de gato de altas prestaciones en cualquier situación, ya sea sobre adherencias, pequeños apoyos o en los desplomes más salvajes. El Ra es un modelo todo terreno.
# Fabricado en tejidos sintéticos, mantiene la forma original durante más tiempo, garantizando un rendimiento óptimo a lo largo de toda su vida.
# Horma ligeramente asimétrica y una curvatura muy leve, lo hacen extremadamente cómodo.
# Modelo para mujer o pies con poco volumen
# Material de microfibra.
# Cierre de velcro.
# Forro de algodón con tratamiento 'TXT'.
# Plantilla TST.
# Media suela 2D PLT 10
# Suela Vibram XS Grip 4 mm.
# Peso de 420 g
#
#         Website: https://www.climbingzone.es/pies-de-gato/404-ra-woman-tenaya.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Katana Laces
#
#         Price: 152,97 €
#
#         Description: Este pie de gato está fabricado con el sistema P3 que permite mantener su forma original con el paso del tiempo incluso después de varios usos logrando un pie de gato muy duradero y con las mismas prestaciones que el primer día.
# El Katana es un pie de gato más neutro y algo menos asimétrico que otros modelos más agresivos de La Sportiva, algo que muchos escaladores aprecian ya que permite escalar más cómodo sin sacrificar la más minima de las prestaciones de precisión.
#
#         Website: https://www.climbingzone.es/pies-de-gato/450-katana-laces-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Boreal Alpha
#
#         Price: 82,97 €
#
#         Description: El pie de gato Alpha está diseñado para ofrecer comodidad y precisión a partes iguales.
# Excelente para iniciarse en la escalada, para entrenamientos en sala o para escaladas largas donde el confort es imprescindible.
# Es un pie de gato que cuenta con la goma Boreal Zenith Quattro 2.0 de 4mm, una de las mas adherentes del mercado. acolchado CHS en el talón  para un mayor confort y cierre de velcro.
# Fabricado en microfibra, cuenta con una entresuela antideformación que le da la rigidez justa para mejorar los apoyos y descansar los gemelos.
#
#         Website: https://www.climbingzone.es/pies-de-gato/325-alpha-boreal.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Mantra
#
#         Price: 129,95 €
#
#         Description: La Sportiva ha dado un giro de tuerca más con el Mantra. Un pie de gato superblando pensado y diseñado para el nuevo estilo de escalada indoor, siempre sobre superficies grandes donde se ha sustituido la precisión por movimientos más dinámicos.
# Cuenta con la tecnología No Edge, que elimina el filo delantero en la puntera para ofrecer mayor superficie de contacto y fricción. Además incorpora tambien la tecnología DTech, que hace lo mismo con los bordes laterales logrando que la suela abrace casi por completo al pie de gato, dandole algo más de ajuste y estabilidad, muy de agradecer en un modelo tan blando.
# Además el Mantra tambien cuenta con el diseño P3 System para un mayor rango dinámico de los pies dentro del pie de gato.
# Todo esto en un modelo superblando, muy cómodo y que ofrecerá las mayores sensaciones al pisar de cuantos pies de gato hay en el mercado. Es casi como escalar descalzo.
# CARACTERISTICAS:
# UPPER: Microfibra combinado con piel natural
# Construcción: Tubular
# Palmilla: No
# Goma: Vibram Xgrip2 1.8mm
# Tecnologias: P3 System, No Edge, D-Tech
#
#         Website: https://www.climbingzone.es/pies-de-gato/683-mantra-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: La Sportiva Theory
#
#         Price: 147,97 €
#
#         Description: El
# Theory es un pie de gato
# evolucionado hacia la escalada indoor y de competición, ultra blando y extremadamente sensible.
# Ajuste
# El
# Theory
# es realmente un pie de gato diseñado bajo el concepto de "bailarina" con un gran empeine elástico al que La Sportiva ha añadido un cierre de velcro para ceñir aún más el pie de gato a la forma del pie y evitar que pueda salirse en movimientos muy exigentes.
# Cuenta con una horma media de construcción tubular más parecida all Python a la horma más ancha del modelo Skwama, que se adapta muy bien al pie. Su
# talón
# , con un nervio central algo más duro y unos laterales muy muy blandos se ajusta también a la perfección, dando una sensación de soporte al pie al más alto nivel, y que ofrece un gran rendimiento sobre superficies planas con una sensibilidad excelente
# Suela
# El Theory monta una goma XSGrip II de Vibram con diferentes espesores para dotar de más sensibilidad al pie de gato allí donde lo necesita. La puntera es donde más goma lleva este modelo, reduciéndose en el canto lateral exterior.
# Poco que añadir al rendimiento de este compuesto. Uno de los más usados en pies de gato de alto nivel donde la adherencia prima sobre otros factores
# Puntera
# Los pies de gato diseñados principalmente para escalada en rocódromos o para competición ofrecen generalmente una puntera más redondeada para conseguir mayor superficie de contacto y aumentar la fricción. En este caso el Theory tiene una puntera más afilada para mejorar su rendimiento en apoyos frontales y para convencer a los escaladores que quieran utilizarlo también en roca, donde acabará siendo un imprescindible si lo tuyo son los desplomes o la escalada en techos
# Materiales
# El Theory está fabricado en microfibra, lo que aporta 1cualidad principal a este pie de gato: Mayor resistencia a ceder, aunque como todos los pies de gato siempre acabará cediendo al menos media talla
# No cuenta con forro interior como no puede ser de otra manera en un pie de gato que busca la máxima sensibilidad.
# Usos
# Este modelo de pie de gato dará las máximas prestaciones sobre resina, donde su sensibilidad y reactividad harán las delicias de quienes adoran escalar en volúmenes y presas de colores, aunque aquellos escaladores que prefieren escalar con pies de gato blandos quedarán prendados de sus cualidades también en roca.
# Datos técnicos:
# Exterior:
# Microfibra combinada con ante en construcción tubular
# Forro:
# Ausente
# Suela: XS Grip II
# Media suela:
# P3 System™
# Cierre: Elastico - Velcro
# Peso:
# 400 gr el par
#
#         Website: https://www.climbingzone.es/pies-de-gato/414-theory-la-sportiva.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Scarpa Vapor V
#
#         Price: 139,97 €
#
#         Description: El Vapor V de Scarpa es perfecto si lo tuyo son las escaladas sobre presa minúscula en muros verticales o placas, ya sea en deportiva o bulder. Verás que en este terreno el Vapor V se siente cómodo y dará sus mejores prestaciones.
# La construcción de este modelo está ideada para dar un mayor soporte al pie cuando recibe el peso de cuerpo haciendo que progresar en apoyos mínimos sea más sencillo y libere al pie de una tensión excesiva.
# Para ello monta una media palmilla de 1.4mm denominada
# Flexan Dynamic
# Cuenta con el
# sistema Tension BI.
# Una banda de goma que refuerza el pie de gato desde la almohadilla de los dedos hacia los tobillos, aportando tensión pero liberando la parte central del pie para recibir algo más de sensibilidad
# CARACTERÍSTICAS TÉCNICAS
# Peso:
# 480gr (par de talla 40)
# Pamilla:
# Si, 1.4mm
# Perfil:
# Curvatura media
# Suela:
# Vibram XS Edge 3.5mm
# Asimetría:
# Asimétrico
# Materiales:
# microfibra y piel natural
#
#         Website: https://www.climbingzone.es/pies-de-gato/589-vapor-v-scarpa.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Tenaya Oasi
#
#         Price: 132,97 €
#
#         Description: El pie de gato OASI de Tenaya nace para que los escaladores más exigentes se queden sin excusas. Ya no podrás echar la culpa a los pies de gato
# Se trata de un pie de gato no excesivamente duro pero que ofrece unas excelentes prestaciones de canteo y una adherencia destacable.
# Suela Vibram XGrip
#
#         Website: https://www.climbingzone.es/pies-de-gato/69-oasi-tenaya.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Boreal Mutant
#
#         Price: 117,97 €
#
#         Description: El nuevo Mutant de Boreal es una enorme evolución del antiguo modelo que la marca española lanzó hace casi una década.
# Las mejoras introducidas hacen de este pie de gato un modelo un gama alta sin objeciones, y que dará unos resultados excelentes en cualquier movimiento, y cuanto más duro mejor.
# El
# Mutant
# incorpora una nueva banda lateral de torsión que favocere un ajuste excelente en el puente del pie mejorando las sensaciones sobre cantos muy pequeños y aumentando el confort general del pie de gato, retornando además parte de la energía del movimiento al talón, lo que hace la unión del pie de gato con el pie sea un de los mejores.
# El engomado del empeine (Friction Skin) hace del
# Mutant
# un aliado perfecto en pasos en los que los empeines juegen un papel importante, optimizando la adherencia y pretegiendo los dedos de los pies de esos dolorosos movimientos, algo que el bulder o viás extremas agradecerás de verdad.
# Sobre la goma de este pie de gato de la marca española
# Boreal
# poco que decir. La goma elegida es la Zenith, seguramente la goma más adherente del mercado tanto en sobre granito, caliza o arenisca.
# Corte:
# Piel serraje
# Goma:
# Boreal Zenith 4-4,5mm
# Forro:
# No
# Peso:
# 460 gas
# Palmilla:
# Special antideformación
#
#         Website: https://www.climbingzone.es/pies-de-gato/172-mutant-boreal.html
#
#
#
#
#
#         Shoes content:
#
#         Model: Boreal Joker Velcro
#
#         Price: 84,97 €
#
#         Description: Este modelo es uno de los usados en entrenamiento por su rapidez de calzado y por su comodidad. Uno de los más solicitados en cursos de escalada por su polivalencia
#
#         Website: https://www.climbingzone.es/pies-de-gato/60-joker-velcro-boreal.html

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]

    stream = openai.chat.completions.create(model=MODEL, messages=messages, stream=True)

    response = ""
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        yield response

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7875
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7875/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
